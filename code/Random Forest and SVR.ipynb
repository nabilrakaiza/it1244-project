# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

import pickle

from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
def preprocess_data(filename, N, points_prior):
    """
    Preprocesses a time series dataset and sets up time series cross-validation folds.

    Args:
        filename (str): Path to CSV file.
        N (int): Window size for rolling and lag features.
        points_prior (int): Number of points to shift for prediction target.

    Returns:
        df (pd.DataFrame)): DataFrame
    """

    df = pd.read_csv(filename)
    feature_columns = ['HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL']

    # Rolling and lag features
    for col in feature_columns:
        df[f"rolling_mean_{col}"] = df[col].rolling(window=N).mean().shift(points_prior)
        df[f"rolling_std_{col}"] = df[col].rolling(window=N).std().shift(points_prior)
        for i in range(1, N + 1):
            df[f'{col}_lag{i + points_prior}'] = df[col].shift(i + points_prior)

    # Drop current columns and missing values
    df = df.drop(columns=feature_columns)
    df = df.dropna().reset_index(drop=True)

    # Time feature extraction
    df["date"] = pd.to_datetime(df["date"])
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    df["dow"] = df["date"].dt.day_of_week
    df["hour"] = df["date"].dt.hour
    df["minute"] = df["date"].dt.minute
    df = df.drop(columns="date")

    # Memory optimization
    for col in df.select_dtypes(include=['float64']).columns:
        df[col] = df[col].astype('float32')
    for col in df.select_dtypes(include=['int64']).columns:
        df[col] = df[col].astype('int32')

    return df

def time_series_split(df, target_col, n_splits=3, max_train_size=None, test_ratio = 0.20):
    """
    splitting time series data into train, val, and test, using time series split
    """
    X = df.drop(columns=[target_col])
    y = df[target_col]

    n_total = len(df)
    n_test = int(n_total * test_ratio)
    split_idx = n_total - n_test

    X_trainval, X_test = X[:split_idx], X[split_idx:]
    y_trainval, y_test = y[:split_idx], y[split_idx:]

    print(f"Train/Val samples: {len(X_trainval)}, Test samples: {len(X_test)}")

    # ---- Time Series Cross-Validation for train/val ----
    tscv = TimeSeriesSplit(n_splits=n_splits, max_train_size=max_train_size)

    return X_trainval, y_trainval, X_test, y_test, tscv

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor

models = [
    # 1. Random Forest Regressor
    ["Random Forest Regressor",
     Pipeline([
         ('scaler', StandardScaler()),
         ('model', RandomForestRegressor(random_state=42, n_jobs=-1))
     ]),
     {
         "model__n_estimators": [100, 300],
         "model__max_depth": [5, 15],
         "model__min_samples_split": [2, 8],
         "model__min_samples_leaf": [1, 3],
     }],

    # 2. Support Vector Regressor (SVR)
    ["Support Vector Regressor (SVR)",
     Pipeline([
         ('scaler', StandardScaler()),
         ('model', SVR())
     ]),
     {
         "model__kernel": ['linear', 'rbf', 'poly'],
         "model__C": [0.1, 1, 10],
         "model__gamma": ['scale', 'auto', 0.1],
         "model__epsilon": [0.1, 0.4],
     }]
]

N_list = [12, 24, 48] # can add 96 if you want (and have enough time)
points_priors = [4, 96, 672]
filenames = ["trans_1.csv", "trans_2.csv"]

# Store the overall best N for each configuration
overall_best_results = {}

for (model_name, model, model_params) in models:
    for filename in filenames:
        for points_prior in points_priors:

            print(f"\n========================================================")
            print(f"Processing: File={filename}, PointsPrior={points_prior}, Model={model_name}")
            print(f"========================================================\n")

            results_per_n = {}
            for N in N_list:
                df = preprocess_data(filename, N = N, points_prior= points_prior)
                X_trainval, y_trainval, X_test, y_test, tscv = time_series_split(df, "OT")

                print("Training Configurations")
                print(f"file: {filename}")
                print(f"N: {N}")
                print(f"points_prior: {points_prior}")
                print(f"model: {model_name}")

                # ---- FEATURE SELECTION using RFE ----
                base_model = XGBRegressor(
                    objective='reg:squarederror',
                    random_state=42,
                    n_estimators=200,
                    learning_rate=0.05,
                    max_depth=5,
                    subsample=0.8
                )

                # Select top 20 features
                print("Selecting top 20 features...")
                rfe = RFE(estimator=base_model, n_features_to_select=20, step=0.1)
                rfe.fit(X_trainval, y_trainval)

                # Mask of selected features
                selected_features = list(X_trainval.columns[rfe.support_])
                print("Top 20 selected features:\n", list(selected_features))

                # Filter columns
                X_trainval_sel = X_trainval[selected_features]
                X_test_sel = X_test[selected_features]

                # GridSearchCV with TimeSeriesSplit
                grid_search = GridSearchCV(
                    estimator=model,
                    param_grid=model_params,
                    cv=tscv,
                    scoring="neg_mean_squared_error",
                    verbose=1,
                    n_jobs=-1
                )

                # Fit using only train/val (no test!)
                print("Training data using train and val...")
                grid_search.fit(X_trainval_sel, y_trainval)

                # Show CV results
                print("Best parameters:", grid_search.best_params_)
                print("Best CV RMSE:", np.sqrt(-grid_search.best_score_))

                # ---- Final evaluation on the hold-out test set ----
                best_model = grid_search.best_estimator_
                y_pred = best_model.predict(X_test_sel)
                test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

                print(f"Final Test RMSE: {test_rmse:.4f}")

                results_per_n[N] = {
                    "rmse": test_rmse,
                    "best_params": grid_search.best_params_,
                    "selected_features": selected_features,
                    "best_model" : best_model
                }

            best_n_value = min(results_per_n.keys(), key=lambda n: results_per_n[n]["rmse"])
            best_result = results_per_n[best_n_value]
            best_model = best_result["best_model"]

            # saving best model
            model_filename = f"Model_{model_name} N_{best_n_value} points_prior_{points_prior} dataset_{filename}.pkl"
            with open(model_filename, 'wb') as file:
                pickle.dump(best_model, file)

            print(f"Model saved to {model_filename}")
            
            print(f"\n--------------------------------------------------------")
            print(f"*** BEST N for {filename}, points_prior: {points_prior}, Model {model_name} ***")
            print(f"Best N: \t\t{best_n_value}")
            print(f"Best Test RMSE: \t{best_result['rmse']:.4f}")
            print(f"Best Hyperparameters: \t{best_result['best_params']}")
            print(f"--------------------------------------------------------\n")
            
            # Store this in the overall results for a final summary
            config_key = (filename, points_prior, model_name)
            overall_best_results[config_key] = {
                "best_n": best_n_value,
                "rmse": best_result['rmse'],
                "best_params": best_result['best_params'],
                "selected_features": best_result['selected_features']
            } 

# 4. Print a final summary of all configurations
print("\n\n===================================")
print("           FINAL SUMMARY           ")
print("===================================")
for config, result in overall_best_results.items():
    print(f"Config (File, Prior, Model): {config}")
    print(f"  -> Best N: {result['best_n']} (RMSE: {result['rmse']:.4f})\n")
# Out:
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=4, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55732, Test samples: 13932
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag14', 'HUFL_lag16', 'rolling_mean_MUFL', 'MUFL_lag14', 'MUFL_lag15', 'MUFL_lag16', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag9', 'rolling_mean_LUFL', 'LUFL_lag12', 'rolling_mean_LULL', 'LULL_lag5', 'LULL_lag16', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# Best CV RMSE: 13.521101461648648
# Final Test RMSE: 7.1539
# Train/Val samples: 55722, Test samples: 13930
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag23', 'HUFL_lag26', 'HUFL_lag27', 'HUFL_lag28', 'rolling_mean_MUFL', 'rolling_std_MUFL', 'MUFL_lag28', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag19', 'LULL_lag23', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 13.416601477121905
# Final Test RMSE: 7.7370
# Train/Val samples: 55703, Test samples: 13925
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'rolling_std_HUFL', 'rolling_mean_HULL', 'rolling_mean_MUFL', 'rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag16', 'MUFL_lag19', 'MUFL_lag43', 'MUFL_lag45', 'MUFL_lag46', 'MUFL_lag47', 'MUFL_lag52', 'rolling_mean_MULL', 'MULL_lag42', 'rolling_mean_LUFL', 'LULL_lag13', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 100}
# Best CV RMSE: 13.605515121355618
# Final Test RMSE: 7.4701
# Model saved to Model_Random Forest Regressor N_12 points_prior_4 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 4, Model Random Forest Regressor ***
# Best N: 		12
# Best Test RMSE: 	7.1539
# Best Hyperparameters: 	{'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=96, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55658, Test samples: 13914
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag108', 'rolling_mean_MUFL', 'MUFL_lag105', 'MUFL_lag106', 'MUFL_lag107', 'MUFL_lag108', 'rolling_mean_MULL', 'MULL_lag98', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag97', 'LULL_lag98', 'LULL_lag99', 'LULL_lag108', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 100}
# Best CV RMSE: 13.384848823931607
# Final Test RMSE: 7.2666
# Train/Val samples: 55648, Test samples: 13912
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'rolling_mean_MUFL', 'MUFL_lag99', 'MUFL_lag105', 'MUFL_lag107', 'MUFL_lag108', 'MUFL_lag110', 'MUFL_lag111', 'MUFL_lag117', 'MUFL_lag120', 'rolling_mean_MULL', 'rolling_mean_LUFL', 'LULL_lag98', 'LULL_lag101', 'LULL_lag102', 'LULL_lag120', 'year', 'month', 'day', 'dow']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 3, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# Best CV RMSE: 12.943434063116337
# Final Test RMSE: 7.4288
# Train/Val samples: 55629, Test samples: 13907
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_HUFL', 'HUFL_lag143', 'rolling_std_MUFL', 'MUFL_lag105', 'MUFL_lag106', 'MUFL_lag107', 'MUFL_lag110', 'MUFL_lag111', 'MUFL_lag139', 'MUFL_lag141', 'MUFL_lag142', 'rolling_mean_MULL', 'LULL_lag140', 'LULL_lag142', 'LULL_lag143', 'LULL_lag144', 'year', 'month', 'day', 'dow']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# Best CV RMSE: 13.969621175966633
# Final Test RMSE: 7.4600
# Model saved to Model_Random Forest Regressor N_12 points_prior_96 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 96, Model Random Forest Regressor ***
# Best N: 		12
# Best Test RMSE: 	7.2666
# Best Hyperparameters: 	{'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 100}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=672, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55197, Test samples: 13799
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag674', 'rolling_mean_HULL', 'HULL_lag673', 'rolling_mean_MUFL', 'MUFL_lag681', 'MUFL_lag683', 'MUFL_lag684', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'MULL_lag676', 'MULL_lag684', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag684', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 5, 'model__min_samples_leaf': 3, 'model__min_samples_split': 8, 'model__n_estimators': 100}
# Best CV RMSE: 14.33207208475884
# Final Test RMSE: 7.0089
# Train/Val samples: 55188, Test samples: 13796
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'rolling_mean_MUFL', 'MUFL_lag679', 'MUFL_lag680', 'MUFL_lag681', 'MUFL_lag682', 'MUFL_lag684', 'MUFL_lag685', 'MUFL_lag686', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag696', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 3, 'model__min_samples_split': 8, 'model__n_estimators': 300}
# Best CV RMSE: 14.352226320292157
# Final Test RMSE: 7.0049
# Train/Val samples: 55168, Test samples: 13792
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'MUFL_lag679', 'MUFL_lag681', 'MUFL_lag684', 'MUFL_lag685', 'MUFL_lag686', 'MUFL_lag687', 'MUFL_lag690', 'rolling_mean_MULL', 'MULL_lag673', 'rolling_mean_LUFL', 'LULL_lag673', 'LULL_lag716', 'LULL_lag719', 'LULL_lag720', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 14.320127045670239
# Final Test RMSE: 7.0035
# Model saved to Model_Random Forest Regressor N_48 points_prior_672 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 672, Model Random Forest Regressor ***
# Best N: 		48
# Best Test RMSE: 	7.0035
# Best Hyperparameters: 	{'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=4, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55732, Test samples: 13932
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag5', 'HUFL_lag6', 'HUFL_lag8', 'rolling_mean_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag16', 'rolling_mean_LUFL', 'LUFL_lag5', 'LUFL_lag6', 'rolling_mean_LULL', 'LULL_lag16', 'year', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 13.95541804003592
# Final Test RMSE: 6.3826
# Train/Val samples: 55722, Test samples: 13930
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag12', 'rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'MUFL_lag7', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'MULL_lag9', 'MULL_lag10', 'MULL_lag12', 'MULL_lag14', 'LUFL_lag5', 'rolling_mean_LULL', 'year', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 300}
# Best CV RMSE: 13.963424348147786
# Final Test RMSE: 6.1972
# Train/Val samples: 55703, Test samples: 13925
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 4
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'MUFL_lag7', 'MUFL_lag42', 'MUFL_lag44', 'MUFL_lag45', 'MUFL_lag46', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'MULL_lag9', 'MULL_lag10', 'MULL_lag11', 'LULL_lag52', 'year', 'month', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 300}
# Best CV RMSE: 13.898393718760326
# Final Test RMSE: 5.8423
# Model saved to Model_Random Forest Regressor N_48 points_prior_4 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 4, Model Random Forest Regressor ***
# Best N: 		48
# Best Test RMSE: 	5.8423
# Best Hyperparameters: 	{'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 300}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=96, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55658, Test samples: 13914
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag97', 'rolling_mean_HULL', 'HULL_lag97', 'rolling_mean_MUFL', 'MUFL_lag97', 'MUFL_lag98', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag108', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag97', 'LULL_lag98', 'LULL_lag106', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 13.432960422905472
# Final Test RMSE: 6.9167
# Train/Val samples: 55648, Test samples: 13912
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_MUFL', 'MUFL_lag97', 'MUFL_lag98', 'MUFL_lag99', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag98', 'MULL_lag99', 'MULL_lag103', 'MULL_lag109', 'rolling_mean_LULL', 'LULL_lag108', 'LULL_lag110', 'LULL_lag114', 'LULL_lag120', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 300}
# Best CV RMSE: 13.14910401752118
# Final Test RMSE: 7.0978
# Train/Val samples: 55629, Test samples: 13907
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 96
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_MUFL', 'MUFL_lag97', 'MUFL_lag99', 'MUFL_lag138', 'MUFL_lag139', 'MUFL_lag141', 'MUFL_lag142', 'MUFL_lag143', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag98', 'MULL_lag99', 'MULL_lag102', 'MULL_lag105', 'MULL_lag106', 'MULL_lag108', 'MULL_lag111', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 13.354951707611947
# Final Test RMSE: 6.3275
# Model saved to Model_Random Forest Regressor N_48 points_prior_96 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 96, Model Random Forest Regressor ***
# Best N: 		48
# Best Test RMSE: 	6.3275
# Best Hyperparameters: 	{'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=672, Model=Random Forest Regressor
# ========================================================
#
# Train/Val samples: 55197, Test samples: 13799
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag673', 'rolling_mean_HULL', 'HULL_lag673', 'HULL_lag683', 'HULL_lag684', 'rolling_mean_MULL', 'MULL_lag673', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag674', 'LULL_lag675', 'LULL_lag680', 'LULL_lag682', 'LULL_lag684', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 3, 'model__min_samples_split': 2, 'model__n_estimators': 300}
# Best CV RMSE: 14.189774218055337
# Final Test RMSE: 7.3022
# Train/Val samples: 55188, Test samples: 13796
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag673', 'rolling_mean_HULL', 'HULL_lag673', 'HULL_lag674', 'HULL_lag695', 'HULL_lag696', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag689', 'LULL_lag692', 'LULL_lag695', 'LULL_lag696', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 8, 'model__n_estimators': 100}
# Best CV RMSE: 14.263729126515157
# Final Test RMSE: 7.4452
# Train/Val samples: 55168, Test samples: 13792
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 672
# model: Random Forest Regressor
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'HULL_lag673', 'HULL_lag674', 'HULL_lag675', 'HULL_lag676', 'HULL_lag679', 'HULL_lag680', 'HULL_lag681', 'HULL_lag683', 'HULL_lag686', 'HULL_lag687', 'MUFL_lag710', 'MUFL_lag716', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'LULL_lag720', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__max_depth': 15, 'model__min_samples_leaf': 3, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# Best CV RMSE: 14.078398498932348
# Final Test RMSE: 7.0506
# Model saved to Model_Random Forest Regressor N_48 points_prior_672 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 672, Model Random Forest Regressor ***
# Best N: 		48
# Best Test RMSE: 	7.0506
# Best Hyperparameters: 	{'model__max_depth': 15, 'model__min_samples_leaf': 3, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=4, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55732, Test samples: 13932
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag14', 'HUFL_lag16', 'rolling_mean_MUFL', 'MUFL_lag14', 'MUFL_lag15', 'MUFL_lag16', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag9', 'rolling_mean_LUFL', 'LUFL_lag12', 'rolling_mean_LULL', 'LULL_lag5', 'LULL_lag16', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 98
#      96 # Fit using only train/val (no test!)
#      97 print("Training data using train and val...")
# ---> 98 grid_search.fit(X_trainval_sel, y_trainval)
#     100 # Show CV results
#     101 print("Best parameters:", grid_search.best_params_)
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1605, in GridSearchCV._run_search(self, evaluate_candidates)
#    1603 def _run_search(self, evaluate_candidates):
#    1604     """Search all candidates in param_grid"""
# -> 1605     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Documents/intinya kuliah/Y2S1/IT1244/Group Project/.venv/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor

models = [
    # 2. Support Vector Regressor (SVR)
    ["Support Vector Regressor (SVR)",
     Pipeline([
         ('scaler', StandardScaler()),
         ('model', SVR())
     ]),
     {
         "model__kernel": ['rbf', 'poly'],
         "model__C": [0.1, 1],
         "model__gamma": ['scale', 'auto'],
         "model__epsilon": [0.1, 0.4],
     }]
]

N_list = [12, 24, 48] # can add 96 if you want (and have enough time)
points_priors = [4, 96, 672]
filenames = ["trans_1.csv", "trans_2.csv"]

# Store the overall best N for each configuration
overall_best_results = {}

for (model_name, model, model_params) in models:
    for filename in filenames:
        for points_prior in points_priors:

            print(f"\n========================================================")
            print(f"Processing: File={filename}, PointsPrior={points_prior}, Model={model_name}")
            print(f"========================================================\n")

            results_per_n = {}
            for N in N_list:
                df = preprocess_data(filename, N = N, points_prior= points_prior)
                X_trainval, y_trainval, X_test, y_test, tscv = time_series_split(df, "OT")

                print("Training Configurations")
                print(f"file: {filename}")
                print(f"N: {N}")
                print(f"points_prior: {points_prior}")
                print(f"model: {model_name}")

                # ---- FEATURE SELECTION using RFE ----
                base_model = XGBRegressor(
                    objective='reg:squarederror',
                    random_state=42,
                    n_estimators=200,
                    learning_rate=0.05,
                    max_depth=5,
                    subsample=0.8
                )

                # Select top 20 features
                print("Selecting top 20 features...")
                rfe = RFE(estimator=base_model, n_features_to_select=20, step=0.1)
                rfe.fit(X_trainval, y_trainval)

                # Mask of selected features
                selected_features = list(X_trainval.columns[rfe.support_])
                print("Top 20 selected features:\n", list(selected_features))

                # Filter columns
                X_trainval_sel = X_trainval[selected_features]
                X_test_sel = X_test[selected_features]

                # GridSearchCV with TimeSeriesSplit
                grid_search = GridSearchCV(
                    estimator=model,
                    param_grid=model_params,
                    cv=tscv,
                    scoring="neg_mean_squared_error",
                    verbose=1,
                    n_jobs=-1
                )

                # Fit using only train/val (no test!)
                print("Training data using train and val...")
                grid_search.fit(X_trainval_sel, y_trainval)

                # Show CV results
                print("Best parameters:", grid_search.best_params_)
                print("Best CV RMSE:", np.sqrt(-grid_search.best_score_))

                # ---- Final evaluation on the hold-out test set ----
                best_model = grid_search.best_estimator_
                y_pred = best_model.predict(X_test_sel)
                test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

                print(f"Final Test RMSE: {test_rmse:.4f}")

                results_per_n[N] = {
                    "rmse": test_rmse,
                    "best_params": grid_search.best_params_,
                    "selected_features": selected_features,
                    "best_model" : best_model
                }

            best_n_value = min(results_per_n.keys(), key=lambda n: results_per_n[n]["rmse"])
            best_result = results_per_n[best_n_value]
            best_model = best_result["best_model"]

            # saving best model
            model_filename = f"Model_{model_name} N_{best_n_value} points_prior_{points_prior} dataset_{filename}.pkl"
            with open(model_filename, 'wb') as file:
                pickle.dump(best_model, file)

            print(f"Model saved to {model_filename}")
            
            print(f"\n--------------------------------------------------------")
            print(f"*** BEST N for {filename}, points_prior: {points_prior}, Model {model_name} ***")
            print(f"Best N: \t\t{best_n_value}")
            print(f"Best Test RMSE: \t{best_result['rmse']:.4f}")
            print(f"Best Hyperparameters: \t{best_result['best_params']}")
            print(f"--------------------------------------------------------\n")
            
            # Store this in the overall results for a final summary
            config_key = (filename, points_prior, model_name)
            overall_best_results[config_key] = {
                "best_n": best_n_value,
                "rmse": best_result['rmse'],
                "best_params": best_result['best_params'],
                "selected_features": best_result['selected_features']
            }

# 4. Print a final summary of all configurations
print("\n\n===================================")
print("           FINAL SUMMARY           ")
print("===================================")
for config, result in overall_best_results.items():
    print(f"Config (File, Prior, Model): {config}")
    print(f"  -> Best N: {result['best_n']} (RMSE: {result['rmse']:.4f})\n")
# Out:
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=4, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55732, Test samples: 13932
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag14', 'HUFL_lag16', 'rolling_mean_MUFL', 'MUFL_lag14', 'MUFL_lag15', 'MUFL_lag16', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag9', 'rolling_mean_LUFL', 'LUFL_lag12', 'rolling_mean_LULL', 'LULL_lag5', 'LULL_lag16', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.547398500287073
# Final Test RMSE: 4.1735
# Train/Val samples: 55722, Test samples: 13930
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag23', 'HUFL_lag26', 'HUFL_lag27', 'HUFL_lag28', 'rolling_mean_MUFL', 'rolling_std_MUFL', 'MUFL_lag28', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag19', 'LULL_lag23', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.632858057294252
# Final Test RMSE: 4.0586
# Train/Val samples: 55703, Test samples: 13925
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'rolling_std_HUFL', 'rolling_mean_HULL', 'rolling_mean_MUFL', 'rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag16', 'MUFL_lag19', 'MUFL_lag43', 'MUFL_lag45', 'MUFL_lag46', 'MUFL_lag47', 'MUFL_lag52', 'rolling_mean_MULL', 'MULL_lag42', 'rolling_mean_LUFL', 'LULL_lag13', 'year', 'month', 'day']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.806432622285088
# Final Test RMSE: 3.8596
# Model saved to Model_Support Vector Regressor (SVR) N_48 points_prior_4 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 4, Model Support Vector Regressor (SVR) ***
# Best N: 		48
# Best Test RMSE: 	3.8596
# Best Hyperparameters: 	{'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=96, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55658, Test samples: 13914
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag108', 'rolling_mean_MUFL', 'MUFL_lag105', 'MUFL_lag106', 'MUFL_lag107', 'MUFL_lag108', 'rolling_mean_MULL', 'MULL_lag98', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag97', 'LULL_lag98', 'LULL_lag99', 'LULL_lag108', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.380990015687068
# Final Test RMSE: 4.0368
# Train/Val samples: 55648, Test samples: 13912
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'rolling_mean_MUFL', 'MUFL_lag99', 'MUFL_lag105', 'MUFL_lag107', 'MUFL_lag108', 'MUFL_lag110', 'MUFL_lag111', 'MUFL_lag117', 'MUFL_lag120', 'rolling_mean_MULL', 'rolling_mean_LUFL', 'LULL_lag98', 'LULL_lag101', 'LULL_lag102', 'LULL_lag120', 'year', 'month', 'day', 'dow']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.472094653422747
# Final Test RMSE: 4.2940
# Train/Val samples: 55629, Test samples: 13907
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_HUFL', 'HUFL_lag143', 'rolling_std_MUFL', 'MUFL_lag105', 'MUFL_lag106', 'MUFL_lag107', 'MUFL_lag110', 'MUFL_lag111', 'MUFL_lag139', 'MUFL_lag141', 'MUFL_lag142', 'rolling_mean_MULL', 'LULL_lag140', 'LULL_lag142', 'LULL_lag143', 'LULL_lag144', 'year', 'month', 'day', 'dow']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.642340008640167
# Final Test RMSE: 3.9334
# Model saved to Model_Support Vector Regressor (SVR) N_48 points_prior_96 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 96, Model Support Vector Regressor (SVR) ***
# Best N: 		48
# Best Test RMSE: 	3.9334
# Best Hyperparameters: 	{'model__C': 0.1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_1.csv, PointsPrior=672, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55197, Test samples: 13799
# Training Configurations
# file: trans_1.csv
# N: 12
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag674', 'rolling_mean_HULL', 'HULL_lag673', 'rolling_mean_MUFL', 'MUFL_lag681', 'MUFL_lag683', 'MUFL_lag684', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'MULL_lag676', 'MULL_lag684', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag684', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.200399346478495
# Final Test RMSE: 4.8916
# Train/Val samples: 55188, Test samples: 13796
# Training Configurations
# file: trans_1.csv
# N: 24
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'rolling_mean_MUFL', 'MUFL_lag679', 'MUFL_lag680', 'MUFL_lag681', 'MUFL_lag682', 'MUFL_lag684', 'MUFL_lag685', 'MUFL_lag686', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag696', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.626260758113734
# Final Test RMSE: 4.9584
# Train/Val samples: 55168, Test samples: 13792
# Training Configurations
# file: trans_1.csv
# N: 48
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'MUFL_lag679', 'MUFL_lag681', 'MUFL_lag684', 'MUFL_lag685', 'MUFL_lag686', 'MUFL_lag687', 'MUFL_lag690', 'rolling_mean_MULL', 'MULL_lag673', 'rolling_mean_LUFL', 'LULL_lag673', 'LULL_lag716', 'LULL_lag719', 'LULL_lag720', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.502051067017128
# Final Test RMSE: 5.0386
# Model saved to Model_Support Vector Regressor (SVR) N_12 points_prior_672 dataset_trans_1.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_1.csv, points_prior: 672, Model Support Vector Regressor (SVR) ***
# Best N: 		12
# Best Test RMSE: 	4.8916
# Best Hyperparameters: 	{'model__C': 0.1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=4, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55732, Test samples: 13932
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag5', 'HUFL_lag6', 'HUFL_lag8', 'rolling_mean_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag16', 'rolling_mean_LUFL', 'LUFL_lag5', 'LUFL_lag6', 'rolling_mean_LULL', 'LULL_lag16', 'year', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 14.174821077952858
# Final Test RMSE: 9.3899
# Train/Val samples: 55722, Test samples: 13930
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag12', 'rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'MUFL_lag7', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'MULL_lag9', 'MULL_lag10', 'MULL_lag12', 'MULL_lag14', 'LUFL_lag5', 'rolling_mean_LULL', 'year', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'auto', 'model__kernel': 'rbf'}
# Best CV RMSE: 12.794991649357266
# Final Test RMSE: 8.5640
# Train/Val samples: 55703, Test samples: 13925
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 4
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_MUFL', 'MUFL_lag5', 'MUFL_lag6', 'MUFL_lag7', 'MUFL_lag42', 'MUFL_lag44', 'MUFL_lag45', 'MUFL_lag46', 'rolling_mean_MULL', 'MULL_lag5', 'MULL_lag6', 'MULL_lag7', 'MULL_lag8', 'MULL_lag9', 'MULL_lag10', 'MULL_lag11', 'LULL_lag52', 'year', 'month', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'auto', 'model__kernel': 'rbf'}
# Best CV RMSE: 13.848090535595471
# Final Test RMSE: 7.1686
# Model saved to Model_Support Vector Regressor (SVR) N_48 points_prior_4 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 4, Model Support Vector Regressor (SVR) ***
# Best N: 		48
# Best Test RMSE: 	7.1686
# Best Hyperparameters: 	{'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'auto', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=96, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55658, Test samples: 13914
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag97', 'rolling_mean_HULL', 'HULL_lag97', 'rolling_mean_MUFL', 'MUFL_lag97', 'MUFL_lag98', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag108', 'rolling_mean_LUFL', 'rolling_mean_LULL', 'LULL_lag97', 'LULL_lag98', 'LULL_lag106', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 12.940618504482195
# Final Test RMSE: 8.9718
# Train/Val samples: 55648, Test samples: 13912
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_MUFL', 'MUFL_lag97', 'MUFL_lag98', 'MUFL_lag99', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag98', 'MULL_lag99', 'MULL_lag103', 'MULL_lag109', 'rolling_mean_LULL', 'LULL_lag108', 'LULL_lag110', 'LULL_lag114', 'LULL_lag120', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 12.659670075718907
# Final Test RMSE: 8.9779
# Train/Val samples: 55629, Test samples: 13907
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 96
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_std_MUFL', 'MUFL_lag97', 'MUFL_lag99', 'MUFL_lag138', 'MUFL_lag139', 'MUFL_lag141', 'MUFL_lag142', 'MUFL_lag143', 'rolling_mean_MULL', 'MULL_lag97', 'MULL_lag98', 'MULL_lag99', 'MULL_lag102', 'MULL_lag105', 'MULL_lag106', 'MULL_lag108', 'MULL_lag111', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 11.850819151781117
# Final Test RMSE: 6.6075
# Model saved to Model_Support Vector Regressor (SVR) N_48 points_prior_96 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 96, Model Support Vector Regressor (SVR) ***
# Best N: 		48
# Best Test RMSE: 	6.6075
# Best Hyperparameters: 	{'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
# ========================================================
# Processing: File=trans_2.csv, PointsPrior=672, Model=Support Vector Regressor (SVR)
# ========================================================
#
# Train/Val samples: 55197, Test samples: 13799
# Training Configurations
# file: trans_2.csv
# N: 12
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HUFL', 'HUFL_lag673', 'rolling_mean_HULL', 'HULL_lag673', 'HULL_lag683', 'HULL_lag684', 'rolling_mean_MULL', 'MULL_lag673', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag674', 'LULL_lag675', 'LULL_lag680', 'LULL_lag682', 'LULL_lag684', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 15.152823171075779
# Final Test RMSE: 9.6596
# Train/Val samples: 55188, Test samples: 13796
# Training Configurations
# file: trans_2.csv
# N: 24
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['HUFL_lag673', 'rolling_mean_HULL', 'HULL_lag673', 'HULL_lag674', 'HULL_lag695', 'HULL_lag696', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'rolling_mean_LULL', 'LULL_lag673', 'LULL_lag689', 'LULL_lag692', 'LULL_lag695', 'LULL_lag696', 'year', 'month', 'day', 'dow', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.4, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 15.243739082632889
# Final Test RMSE: 9.4231
# Train/Val samples: 55168, Test samples: 13792
# Training Configurations
# file: trans_2.csv
# N: 48
# points_prior: 672
# model: Support Vector Regressor (SVR)
# Selecting top 20 features...
# Top 20 selected features:
#  ['rolling_mean_HULL', 'HULL_lag673', 'HULL_lag674', 'HULL_lag675', 'HULL_lag676', 'HULL_lag679', 'HULL_lag680', 'HULL_lag681', 'HULL_lag683', 'HULL_lag686', 'HULL_lag687', 'MUFL_lag710', 'MUFL_lag716', 'rolling_mean_MULL', 'MULL_lag673', 'MULL_lag674', 'LULL_lag720', 'month', 'day', 'hour']
# Training data using train and val...
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# Best parameters: {'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# Best CV RMSE: 14.177573873240496
# Final Test RMSE: 6.4664
# Model saved to Model_Support Vector Regressor (SVR) N_48 points_prior_672 dataset_trans_2.csv.pkl
#
# --------------------------------------------------------
# *** BEST N for trans_2.csv, points_prior: 672, Model Support Vector Regressor (SVR) ***
# Best N: 		48
# Best Test RMSE: 	6.4664
# Best Hyperparameters: 	{'model__C': 1, 'model__epsilon': 0.1, 'model__gamma': 'scale', 'model__kernel': 'rbf'}
# --------------------------------------------------------
#
#
#
# ===================================
#            FINAL SUMMARY
# ===================================
# Config (File, Prior, Model): ('trans_1.csv', 4, 'Support Vector Regressor (SVR)')
#   -> Best N: 48 (RMSE: 3.8596)
#
# Config (File, Prior, Model): ('trans_1.csv', 96, 'Support Vector Regressor (SVR)')
#   -> Best N: 48 (RMSE: 3.9334)
#
# Config (File, Prior, Model): ('trans_1.csv', 672, 'Support Vector Regressor (SVR)')
#   -> Best N: 12 (RMSE: 4.8916)
#
# Config (File, Prior, Model): ('trans_2.csv', 4, 'Support Vector Regressor (SVR)')
#   -> Best N: 48 (RMSE: 7.1686)
#
# Config (File, Prior, Model): ('trans_2.csv', 96, 'Support Vector Regressor (SVR)')
#   -> Best N: 48 (RMSE: 6.6075)
#
# Config (File, Prior, Model): ('trans_2.csv', 672, 'Support Vector Regressor (SVR)')
#   -> Best N: 48 (RMSE: 6.4664)
